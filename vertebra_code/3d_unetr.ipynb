# %%
import nibabel as nib
import os
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Read the dataset

# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt

# 폴더 경로 설정
base_path = "/workspace/eli"
folders = {
    "train": "01_training",
    "val": "02_validation",
    "test": "03_test"
}

# 다양한 파일 이름 패턴 목록 (이미지와 마스크 파일 분리)
possible_image_patterns = [
    "{patient_number}_CT-ax.nii.gz",
    "{patient_number}.nii.gz",
    "{patient_number}_CT-iso.nii.gz"
]

possible_mask_patterns = [
    "{patient_number}_CT-ax_seg.nii.gz",
    "{patient_number}_seg.nii.gz",
    "{patient_number}_CT-iso_seg.nii.gz"
]

# 각 폴더에서 환자 데이터를 불러오는 함수
def load_nii_files(data_type):
    image_arrays = []
    mask_arrays = []
    
    folder_path = os.path.join(base_path, folders[data_type])
    
    # 환자 번호 폴더 목록 가져오기
    patients_numbers = os.listdir(folder_path)
    
    for patient_number in patients_numbers:
        image_path = None
        mask_path = None
        
        # 이미지 파일 경로 찾기
        for img_pattern in possible_image_patterns:
            temp_image_path = os.path.join(folder_path, patient_number, img_pattern.format(patient_number=patient_number))
            
            if os.path.exists(temp_image_path):
                image_path = temp_image_path
                break
        
        # 마스크 파일 경로 찾기
        for mask_pattern in possible_mask_patterns:
            temp_mask_path = os.path.join(folder_path, patient_number, mask_pattern.format(patient_number=patient_number))
            
            if os.path.exists(temp_mask_path):
                mask_path = temp_mask_path
                break
        
        # 경로 출력 및 Nii 파일 로드
        if image_path and mask_path:
            print(f"Loading image: {image_path}")
            print(f"Loading mask: {mask_path}")
            
            image = nib.load(image_path).get_fdata()
            mask = nib.load(mask_path).get_fdata()
            
            image_arrays.append(image)
            mask_arrays.append(mask)
        else:
            print(f"Warning: Missing files for patient {patient_number}")
    
    return image_arrays, mask_arrays

# 트레이닝, 검증, 테스트 데이터 불러오기
train_image_array, train_mask_array = load_nii_files("train")
val_image_array, val_mask_array = load_nii_files("val")
test_image_array, test_mask_array = load_nii_files("test")
# Out:
# Loading image: /workspace/eli/01_training/verse825/verse825_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse825/verse825_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse091/verse091.nii.gz
# Loading mask: /workspace/eli/01_training/verse091/verse091_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse097/verse097.nii.gz
# Loading mask: /workspace/eli/01_training/verse097/verse097_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse586/verse586_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse586/verse586_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/GL003/GL003.nii.gz
# Loading mask: /workspace/eli/01_training/GL003/GL003_seg.nii.gz
# Warning: Missing files for patient verse139
# Loading image: /workspace/eli/01_training/verse539/verse539_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse539/verse539_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse544/verse544.nii.gz
# Loading mask: /workspace/eli/01_training/verse544/verse544_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse527/verse527.nii.gz
# Loading mask: /workspace/eli/01_training/verse527/verse527_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse113/verse113.nii.gz
# Loading mask: /workspace/eli/01_training/verse113/verse113_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse005/verse005.nii.gz
# Loading mask: /workspace/eli/01_training/verse005/verse005_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse521/verse521.nii.gz
# Loading mask: /workspace/eli/01_training/verse521/verse521_seg.nii.gz
# Loading image: /workspace/eli/01_training/GL453/GL453_CT-ax.nii.gz
# Loading mask: /workspace/eli/01_training/GL453/GL453_CT-ax_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse564/verse564_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse564/verse564_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/GL247/GL247.nii.gz
# Loading mask: /workspace/eli/01_training/GL247/GL247_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse008/verse008.nii.gz
# Loading mask: /workspace/eli/01_training/verse008/verse008_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse033/verse033.nii.gz
# Loading mask: /workspace/eli/01_training/verse033/verse033_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse808/verse808_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse808/verse808_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse532/verse532.nii.gz
# Loading mask: /workspace/eli/01_training/verse532/verse532_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse823/verse823_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse823/verse823_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse056/verse056.nii.gz
# Loading mask: /workspace/eli/01_training/verse056/verse056_seg.nii.gz
# Warning: Missing files for patient verse112
# Warning: Missing files for patient verse257
# Loading image: /workspace/eli/01_training/verse594/verse594.nii.gz
# Loading mask: /workspace/eli/01_training/verse594/verse594_seg.nii.gz
# Loading image: /workspace/eli/01_training/GL240/GL240_CT-ax.nii.gz
# Loading mask: /workspace/eli/01_training/GL240/GL240_CT-ax_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse818/verse818_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse818/verse818_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/GL090/GL090_CT-ax.nii.gz
# Loading mask: /workspace/eli/01_training/GL090/GL090_CT-ax_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse082/verse082_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse082/verse082_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse506/verse506_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse506/verse506_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse536/verse536.nii.gz
# Loading mask: /workspace/eli/01_training/verse536/verse536_seg.nii.gz
# Warning: Missing files for patient verse631
# Loading image: /workspace/eli/01_training/verse104/verse104_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse104/verse104_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse584/verse584.nii.gz
# Loading mask: /workspace/eli/01_training/verse584/verse584_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse629/verse629_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse629/verse629_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse407
# Loading image: /workspace/eli/01_training/verse646/verse646_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse646/verse646_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse015/verse015.nii.gz
# Loading mask: /workspace/eli/01_training/verse015/verse015_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse641/verse641_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse641/verse641_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse525/verse525.nii.gz
# Loading mask: /workspace/eli/01_training/verse525/verse525_seg.nii.gz
# Warning: Missing files for patient verse403
# Loading image: /workspace/eli/01_training/verse145/verse145.nii.gz
# Loading mask: /workspace/eli/01_training/verse145/verse145_seg.nii.gz
# Warning: Missing files for patient verse588
# Loading image: /workspace/eli/01_training/GL047/GL047.nii.gz
# Loading mask: /workspace/eli/01_training/GL047/GL047_seg.nii.gz
# Loading image: /workspace/eli/01_training/GL124/GL124_CT-ax.nii.gz
# Loading mask: /workspace/eli/01_training/GL124/GL124_CT-ax_seg.nii.gz
# Warning: Missing files for patient verse415
# Loading image: /workspace/eli/01_training/verse807/verse807_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse807/verse807_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse254/verse254.nii.gz
# Loading mask: /workspace/eli/01_training/verse254/verse254_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse507/verse507.nii.gz
# Loading mask: /workspace/eli/01_training/verse507/verse507_seg.nii.gz
# Warning: Missing files for patient verse605
# Loading image: /workspace/eli/01_training/verse619/verse619_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse619/verse619_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse557/verse557.nii.gz
# Loading mask: /workspace/eli/01_training/verse557/verse557_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse833/verse833_CT-ax.nii.gz
# Loading mask: /workspace/eli/01_training/verse833/verse833_CT-ax_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse127/verse127.nii.gz
# Loading mask: /workspace/eli/01_training/verse127/verse127_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse088/verse088.nii.gz
# Loading mask: /workspace/eli/01_training/verse088/verse088_seg.nii.gz
# Loading image: /workspace/eli/01_training/GL295/GL295_CT-ax.nii.gz
# Loading mask: /workspace/eli/01_training/GL295/GL295_CT-ax_seg.nii.gz
# Warning: Missing files for patient verse561
# Warning: Missing files for patient verse593
# Warning: Missing files for patient verse410
# Warning: Missing files for patient verse141
# Loading image: /workspace/eli/01_training/verse577/verse577_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse577/verse577_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse642
# Loading image: /workspace/eli/01_training/verse835/verse835_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse835/verse835_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse111/verse111.nii.gz
# Loading mask: /workspace/eli/01_training/verse111/verse111_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse537/verse537.nii.gz
# Loading mask: /workspace/eli/01_training/verse537/verse537_seg.nii.gz
# Warning: Missing files for patient verse409
# Loading image: /workspace/eli/01_training/verse500/verse500.nii.gz
# Loading mask: /workspace/eli/01_training/verse500/verse500_seg.nii.gz
# Warning: Missing files for patient verse408
# Warning: Missing files for patient verse401
# Loading image: /workspace/eli/01_training/verse541/verse541.nii.gz
# Loading mask: /workspace/eli/01_training/verse541/verse541_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse096/verse096.nii.gz
# Loading mask: /workspace/eli/01_training/verse096/verse096_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse811/verse811_CT-ax.nii.gz
# Loading mask: /workspace/eli/01_training/verse811/verse811_CT-ax_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse034/verse034.nii.gz
# Loading mask: /workspace/eli/01_training/verse034/verse034_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse565/verse565_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse565/verse565_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse411
# Loading image: /workspace/eli/01_training/verse824/verse824_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse824/verse824_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse542/verse542_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse542/verse542_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/GL364/GL364_CT-ax.nii.gz
# Loading mask: /workspace/eli/01_training/GL364/GL364_CT-ax_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse031/verse031.nii.gz
# Loading mask: /workspace/eli/01_training/verse031/verse031_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse581/verse581_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse581/verse581_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse004/verse004.nii.gz
# Loading mask: /workspace/eli/01_training/verse004/verse004_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse519/verse519_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse519/verse519_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse510/verse510_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse510/verse510_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse504/verse504.nii.gz
# Loading mask: /workspace/eli/01_training/verse504/verse504_seg.nii.gz
# Warning: Missing files for patient verse413
# Warning: Missing files for patient verse402
# Warning: Missing files for patient verse151
# Loading image: /workspace/eli/01_training/verse534/verse534.nii.gz
# Loading mask: /workspace/eli/01_training/verse534/verse534_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse533/verse533.nii.gz
# Loading mask: /workspace/eli/01_training/verse533/verse533_seg.nii.gz
# Warning: Missing files for patient verse405
# Loading image: /workspace/eli/01_training/GL016/GL016.nii.gz
# Loading mask: /workspace/eli/01_training/GL016/GL016_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse503/verse503.nii.gz
# Loading mask: /workspace/eli/01_training/verse503/verse503_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse820/verse820_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse820/verse820_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse518/verse518.nii.gz
# Loading mask: /workspace/eli/01_training/verse518/verse518_seg.nii.gz
# Warning: Missing files for patient verse406
# Loading image: /workspace/eli/01_training/verse596/verse596_CT-iso.nii.gz
# Loading mask: /workspace/eli/01_training/verse596/verse596_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse122/verse122.nii.gz
# Loading mask: /workspace/eli/01_training/verse122/verse122_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse135/verse135.nii.gz
# Loading mask: /workspace/eli/01_training/verse135/verse135_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse075/verse075.nii.gz
# Loading mask: /workspace/eli/01_training/verse075/verse075_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse514/verse514.nii.gz
# Loading mask: /workspace/eli/01_training/verse514/verse514_seg.nii.gz
# Loading image: /workspace/eli/01_training/verse535/verse535.nii.gz
# Loading mask: /workspace/eli/01_training/verse535/verse535_seg.nii.gz
# Warning: Missing files for patient verse717
# Warning: Missing files for patient verse623
# Warning: Missing files for patient verse018
# Warning: Missing files for patient verse769
# Loading image: /workspace/eli/02_validation/verse805/verse805_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse805/verse805_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse719
# Loading image: /workspace/eli/02_validation/verse505/verse505_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse505/verse505_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse556/verse556_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse556/verse556_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse640/verse640_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse640/verse640_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse753
# Warning: Missing files for patient verse412
# Loading image: /workspace/eli/02_validation/verse802/verse802_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse802/verse802_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse627/verse627_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse627/verse627_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse269/verse269_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse269/verse269_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL352
# Warning: Missing files for patient verse047
# Loading image: /workspace/eli/02_validation/verse705/verse705_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse705/verse705_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse715/verse715_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse715/verse715_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse713
# Warning: Missing files for patient verse709
# Warning: Missing files for patient verse701
# Loading image: /workspace/eli/02_validation/verse547/verse547_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse547/verse547_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL099
# Loading image: /workspace/eli/02_validation/verse600/verse600_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse600/verse600_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse576/verse576_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse576/verse576_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse707/verse707_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse707/verse707_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse821/verse821_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse821/verse821_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse585
# Warning: Missing files for patient verse559
# Loading image: /workspace/eli/02_validation/verse093/verse093_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse093/verse093_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL380
# Loading image: /workspace/eli/02_validation/verse643/verse643_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse643/verse643_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse817/verse817_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse817/verse817_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse522/verse522_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse522/verse522_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL479
# Loading image: /workspace/eli/02_validation/verse621/verse621_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse621/verse621_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL068
# Warning: Missing files for patient verse755
# Loading image: /workspace/eli/02_validation/verse645/verse645_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse645/verse645_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse635/verse635_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse635/verse635_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse757
# Loading image: /workspace/eli/02_validation/verse814/verse814_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse814/verse814_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse530/verse530_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse530/verse530_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL045
# Loading image: /workspace/eli/02_validation/verse580/verse580_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse580/verse580_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse400
# Loading image: /workspace/eli/02_validation/verse603/verse603_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse603/verse603_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse264/verse264_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse264/verse264_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse511/verse511_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse511/verse511_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse013
# Warning: Missing files for patient verse252
# Warning: Missing files for patient verse531
# Warning: Missing files for patient verse644
# Warning: Missing files for patient verse041
# Loading image: /workspace/eli/02_validation/verse816/verse816_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse816/verse816_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse592/verse592_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse592/verse592_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse023
# Loading image: /workspace/eli/02_validation/verse529/verse529_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse529/verse529_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse615/verse615_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse615/verse615_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse513/verse513_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse513/verse513_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL017
# Loading image: /workspace/eli/02_validation/verse601/verse601_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse601/verse601_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse022/verse022_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse022/verse022_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse614/verse614_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse614/verse614_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse598/verse598_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse598/verse598_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL153
# Loading image: /workspace/eli/02_validation/verse553/verse553_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse553/verse553_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse750/verse750_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse750/verse750_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse545/verse545_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse545/verse545_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse636/verse636_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse636/verse636_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse759
# Loading image: /workspace/eli/02_validation/verse612/verse612_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse612/verse612_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse404
# Warning: Missing files for patient verse763
# Loading image: /workspace/eli/02_validation/verse080/verse080_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse080/verse080_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse806
# Warning: Missing files for patient verse711
# Loading image: /workspace/eli/02_validation/verse571/verse571_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse571/verse571_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse761
# Warning: Missing files for patient GL144
# Loading image: /workspace/eli/02_validation/verse549/verse549_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse549/verse549_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL059
# Loading image: /workspace/eli/02_validation/verse767/verse767_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse767/verse767_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse067
# Loading image: /workspace/eli/02_validation/verse569/verse569_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse569/verse569_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse609/verse609_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse609/verse609_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse765/verse765_CT-ax.nii.gz
# Loading mask: /workspace/eli/02_validation/verse765/verse765_CT-ax_seg.nii.gz
# Warning: Missing files for patient verse024
# Loading image: /workspace/eli/02_validation/verse618/verse618_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse618/verse618_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse508/verse508_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse508/verse508_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse554/verse554_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse554/verse554_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse815/verse815_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse815/verse815_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse606/verse606_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse606/verse606_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse073/verse073_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse073/verse073_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse703/verse703_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse703/verse703_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse573/verse573_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse573/verse573_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse125/verse125_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse125/verse125_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/02_validation/verse826/verse826_CT-iso.nii.gz
# Loading mask: /workspace/eli/02_validation/verse826/verse826_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse276
# Warning: Missing files for patient verse016
# Warning: Missing files for patient verse029
# Warning: Missing files for patient verse050
# Loading image: /workspace/eli/03_test/verse648/verse648_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse648/verse648_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse801/verse801_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse801/verse801_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse085/verse085_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse085/verse085_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse714/verse714_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse714/verse714_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse540/verse540_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse540/verse540_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse417
# Loading image: /workspace/eli/03_test/verse092/verse092_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse092/verse092_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse751
# Loading image: /workspace/eli/03_test/verse271/verse271_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse271/verse271_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse706
# Warning: Missing files for patient verse700
# Loading image: /workspace/eli/03_test/verse546/verse546_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse546/verse546_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse752/verse752_CT-ax.nii.gz
# Loading mask: /workspace/eli/03_test/verse752/verse752_CT-ax_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse599/verse599_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse599/verse599_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse613/verse613_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse613/verse613_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse590/verse590_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse590/verse590_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse119
# Warning: Missing files for patient GL195
# Loading image: /workspace/eli/03_test/verse804/verse804_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse804/verse804_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse143/verse143_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse143/verse143_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse712/verse712_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse712/verse712_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL428
# Warning: Missing files for patient verse813
# Warning: Missing files for patient GL216
# Warning: Missing files for patient verse647
# Loading image: /workspace/eli/03_test/verse764/verse764_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse764/verse764_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL492
# Loading image: /workspace/eli/03_test/verse708/verse708_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse708/verse708_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse597/verse597_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse597/verse597_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse572
# Loading image: /workspace/eli/03_test/verse756/verse756_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse756/verse756_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse260
# Warning: Missing files for patient verse414
# Loading image: /workspace/eli/03_test/verse570/verse570_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse570/verse570_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse089
# Warning: Missing files for patient verse416
# Warning: Missing files for patient GL279
# Loading image: /workspace/eli/03_test/verse555/verse555_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse555/verse555_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse517/verse517_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse517/verse517_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse760/verse760_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse760/verse760_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse526/verse526_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse526/verse526_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse754
# Loading image: /workspace/eli/03_test/verse524/verse524_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse524/verse524_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse617/verse617_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse617/verse617_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL348
# Warning: Missing files for patient verse055
# Loading image: /workspace/eli/03_test/verse651/verse651_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse651/verse651_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse552/verse552_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse552/verse552_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse718/verse718_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse718/verse718_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse702
# Loading image: /workspace/eli/03_test/verse149/verse149_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse149/verse149_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse101/verse101_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse101/verse101_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse650/verse650_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse650/verse650_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse620/verse620_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse620/verse620_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse604/verse604_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse604/verse604_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse758
# Loading image: /workspace/eli/03_test/verse217/verse217_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse217/verse217_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse502/verse502_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse502/verse502_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse587/verse587_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse587/verse587_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse616/verse616_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse616/verse616_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL108
# Loading image: /workspace/eli/03_test/verse762/verse762_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse762/verse762_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse509/verse509_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse509/verse509_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse710/verse710_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse710/verse710_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse154/verse154_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse154/verse154_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse591/verse591_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse591/verse591_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse582/verse582_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse582/verse582_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse512/verse512_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse512/verse512_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse626/verse626_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse626/verse626_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse560/verse560_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse560/verse560_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse131
# Loading image: /workspace/eli/03_test/verse138/verse138_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse138/verse138_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse768/verse768_CT-ax.nii.gz
# Loading mask: /workspace/eli/03_test/verse768/verse768_CT-ax_seg.nii.gz
# Warning: Missing files for patient GL146
# Loading image: /workspace/eli/03_test/verse130/verse130_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse130/verse130_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse563/verse563_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse563/verse563_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse070/verse070_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse070/verse070_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse066
# Warning: Missing files for patient verse020
# Loading image: /workspace/eli/03_test/verse550/verse550_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse550/verse550_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse766/verse766_CT-ax.nii.gz
# Loading mask: /workspace/eli/03_test/verse766/verse766_CT-ax_seg.nii.gz
# Warning: Missing files for patient verse607
# Warning: Missing files for patient verse558
# Loading image: /workspace/eli/03_test/verse602/verse602_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse602/verse602_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse054
# Warning: Missing files for patient verse649
# Loading image: /workspace/eli/03_test/verse578/verse578_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse578/verse578_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse236/verse236_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse236/verse236_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL217
# Loading image: /workspace/eli/03_test/verse803/verse803_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse803/verse803_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse551/verse551_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse551/verse551_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse810/verse810_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse810/verse810_CT-iso_seg.nii.gz
# Warning: Missing files for patient verse083
# Loading image: /workspace/eli/03_test/verse108/verse108_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse108/verse108_CT-iso_seg.nii.gz
# Warning: Missing files for patient GL419
# Loading image: /workspace/eli/03_test/verse809/verse809_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse809/verse809_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse704/verse704_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse704/verse704_CT-iso_seg.nii.gz
# Loading image: /workspace/eli/03_test/verse716/verse716_CT-iso.nii.gz
# Loading mask: /workspace/eli/03_test/verse716/verse716_CT-iso_seg.nii.gz

# %% [markdown]
# # Make the Dataloader

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

class MedicalDataset(Dataset):
    def __init__(self, images, masks):
        self.images = images
        self.masks = masks

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        mask = self.masks[idx]

        # 필요시 numpy 배열을 tensor로 변환하고 차원 추가 (1, Depth, Height, Width)
        image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)  # (1, Depth, Height, Width)
        mask = torch.tensor(mask, dtype=torch.float32).unsqueeze(0)    # (1, Depth, Height, Width)

        # 이미지와 마스크를 64x64x64로 리사이즈 (3D interpolate 사용)
        image = F.interpolate(image.unsqueeze(0), size=(64, 64, 64), mode='trilinear', align_corners=True).squeeze(0)
        mask = F.interpolate(mask.unsqueeze(0), size=(64, 64, 64), mode='trilinear', align_corners=True).squeeze(0)

        return image, mask

# 데이터셋 생성
train_dataset = MedicalDataset(train_image_array, train_mask_array)
val_dataset = MedicalDataset(val_image_array, val_mask_array)
test_dataset = MedicalDataset(test_image_array, test_mask_array)

# DataLoader 생성
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# 확인용 출력
for images, masks in train_loader:
    print("Image shape:", images.shape)
    print("Mask shape:", masks.shape)
    break  # 첫 배치만 확인
# Out:
# Image shape: torch.Size([1, 1, 64, 64, 64])
# Mask shape: torch.Size([1, 1, 64, 64, 64])
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Model Architecture

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class TransformerBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(TransformerBlock, self).__init__()
        self.attn = nn.MultiheadAttention(embed_dim=in_channels, num_heads=4)
        self.fc1 = nn.Linear(in_channels, out_channels)
        self.fc2 = nn.Linear(out_channels, in_channels)
        self.norm1 = nn.LayerNorm(in_channels)
        self.norm2 = nn.LayerNorm(in_channels)

    def forward(self, x):
        # Self-Attention
        attn_out, _ = self.attn(x, x, x)
        x = self.norm1(x + attn_out)

        # Feed Forward
        ff_out = F.relu(self.fc1(x))
        x = self.norm2(x + self.fc2(ff_out))

        return x

class UNet3D(nn.Module):
    def __init__(self, in_channels=1, num_classes=2):
        super(UNet3D, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv3d(in_channels, 32, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=2, stride=2),
            nn.Conv3d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=2, stride=2),
        )
        
        self.transformer = TransformerBlock(in_channels=64 * 16 * 16 * 16, out_channels=128)

        self.decoder = nn.Sequential(
            nn.ConvTranspose3d(64, 32, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv3d(32, num_classes, kernel_size=1)
        )

    def forward(self, x):
        # Encoder
        x = self.encoder(x)
        
        # Flatten for transformer
        b, c, d, h, w = x.shape
        x = x.view(b, c, -1)  # (B, C, D*H*W)
        x = x.permute(0, 2, 1)  # (B, D*H*W, C)

        # Transformer
        x = self.transformer(x)
        
        # Reshape back to 3D
        x = x.permute(0, 2, 1).view(b, c, d, h, w)  # (B, C, D, H, W)

        # Decoder
        x = self.decoder(x)
        return x

# Instantiate the model
model = UNet3D(in_channels=1, num_classes=2)

# %%
def iou(preds, targets, smooth=1e-6):
    preds = preds > 0.5  # 이진 분류를 위한 임계값
    targets = targets > 0.5
    intersection = (preds & targets).float().sum((1, 2, 3))  # 각 배치의 교집합
    union = (preds | targets).float().sum((1, 2, 3))  # 각 배치의 합집합
    iou_score = (intersection + smooth) / (union + smooth)  # IoU 계산
    return iou_score.mean()  # 평균 IoU 반환

def dice_loss(preds, targets, smooth=1e-6):
    preds = preds.sigmoid()  # sigmoid로 이진 분류 확률값으로 변환
    targets = targets > 0.5  # 마스크를 이진화

    intersection = (preds * targets).sum(dim=(1, 2, 3, 4))
    dice = (2. * intersection + smooth) / (preds.sum(dim=(1, 2, 3, 4)) + targets.sum(dim=(1, 2, 3, 4)) + smooth)

    return 1 - dice.mean()

import torch.optim as optim

# Hyperparameters
num_epochs = 1000  # Number of epochs to train
learning_rate = 1e-6  # Learning rate
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')  # Use GPU if available

# Move model to device
model = UNet3D(in_channels=1, num_classes=2).to(device)

# Loss function and optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training function
def train_one_epoch(train_loader, model, optimizer):
    model.train()  # Set model to training mode
    total_loss = 0.0

    for images, masks in train_loader:
        # Move data to the selected device
        images, masks = images.to(device), masks.to(device)

        # GPU 메모리 정리
        torch.cuda.empty_cache()  # 이 위치에서 GPU 메모리 정리

        # Forward pass
        outputs = model(images)

        # Compute loss
        loss = dice_loss(outputs, masks)
        total_loss += loss.item()

        # Backward pass and optimization
        optimizer.zero_grad()  # Clear gradients
        loss.backward()  # Backpropagation
        optimizer.step()  # Update parameters

    return total_loss / len(train_loader)

# Validation function
def validate_one_epoch(val_loader, model):
    model.eval()  # Set model to evaluation mode
    total_loss = 0.0
    total_iou = 0.0

    with torch.no_grad():  # Disable gradient tracking
        for images, masks in val_loader:
            images, masks = images.to(device), masks.to(device)

            # GPU 메모리 정리
            torch.cuda.empty_cache()  # 이 위치에서 GPU 메모리 정리

            # Forward pass
            outputs = model(images)

            # Compute loss
            loss = dice_loss(outputs, masks)
            total_loss += loss.item()

            # Calculate IoU
            iou_score = iou(outputs, masks)
            total_iou += iou_score.item()

    return total_loss / len(val_loader), total_iou / len(val_loader)

# Training loop with model saving
best_val_loss = float('inf')  # To track the best validation loss

for epoch in range(num_epochs):
    train_loss = train_one_epoch(train_loader, model, optimizer)
    val_loss, val_iou = validate_one_epoch(val_loader, model)

    print(f'Epoch {epoch + 1}/{num_epochs}, '
          f'Train Loss: {train_loss:.4f}, '
          f'Validation Loss: {val_loss:.4f}, '
          f'Validation IoU: {val_iou:.4f}')

    # Save the model if validation loss has improved
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), f'unetr_best_epoch.pth')
        print(f"Model saved at epoch {epoch + 1} with validation loss {val_loss:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 26
#      23 device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')  # Use GPU if available
#      25 # Move model to device
# ---> 26 model = model.to(device)
#      28 # Loss function and optimizer
#      29 optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#
# File ~/miniconda3/envs/vertebra/lib/python3.12/site-packages/torch/nn/modules/module.py:1174, in Module.to(self, *args, **kwargs)
#    1171         else:
#    1172             raise
# -> 1174 return self._apply(convert)
#
# AttributeError: 'torch.device' object has no attribute '_apply'
